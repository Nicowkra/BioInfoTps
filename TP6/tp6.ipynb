# %% [markdown]
# # 1. Navegando la información genómica disponible en Target-Pathogen.

# %% [markdown]
# (Ejercicio hecho analizando Mycobacterium tuberculosis H37Rv con gene Rv2764c)

# %% [markdown]
# ## a. Recorra la página y observe;
#
# i. ¿Es esencial?
# ii. ¿En qué vías metabólicas participa?
# iii. ¿Es drogable?
# iv. Para el genoma de tuberculosis se curaron datos de 4 trabajos de
# expresión génica (hipoxia, infección en modelos murinos, hambreado, estrés
# de RNOS) en diferentes modelos que simulan las condiciones que enfrenta el
# bacilo dentro del macrófago. En qué modelos de infección se encuentra
# sobreexpresada?

# %% [markdown]
# i. Sí, es esencial.
# iii. Sí, es altamente drogable.

# %% [markdown]
# ![image.png](attachment:3c8872d5-1a8b-4257-b01e-3266f2a139ff.png)

# %% [markdown]
# ii. Son las siguientes:

# %% [markdown]
# ![Captura de pantalla 2026-06-19 114824.png](attachment:3ee853a9-715a-4984-af69-da067ce9508a.png)

# %% [markdown]
# iv.

# %% [markdown]
# ![image.png](attachment:d3ac0681-8371-41b8-a542-b64af2732e1b.png)

# %% [markdown]
#  ## b. Seleccione la estructura más completa que encuentre en la solapa Structures (4fqs). ¿La estructura fue obtenida experimentalmente o in silico??

# %% [markdown]
# ![image.png](attachment:adfc213d-ae8e-466c-93c7-b0c351a88fc8.png)

# %% [markdown]
# Como vemos, la estructura más completa (4fqs) fue obtenida experimentalmente.

# %% [markdown]
# ## c. Observe la lista de pockets, ¿cuántos pockets con score de drogabilidad mayor a 0.2 encuentra en la estructura? ¿Cuántos son drogables?. Seleccione el más drogable. Cliquee sobre “atoms” y cambie a “alpha” (¿Qué son las alpha-spheres?). En “feature list” seleccione “drug binding”ng”

# %% [markdown]
# ![image.png](attachment:d32f307e-2358-4f49-9b64-f825b56f33c3.png)

# %% [markdown]
# Como podemos observar hay 4 pockets con un score mayor a 0.2. Además, de estos hay 2 que son drogables, ya que poseen una drogabilidad mayor a 0.5. Las alpha spheres son conceptos geometricos que se usan para mapear la superficie tridimensional de las proteínas. Se suelen agrupar varias de estas para detectar y medir pockets.

# %% [markdown]
# Sin seleccionar drug binding:

# %% [markdown]
# ![image.png](attachment:e1898571-8d29-4a2d-8b74-64fdbf4cef6b.png)

# %% [markdown]
# Al seleccionarlo:

# %% [markdown]
# ![image.png](attachment:0c23cc23-1625-4acd-84ae-0b0674a08fea.png)

# %% [markdown]
# ## d. Con la información aquí analizada, ¿creería que la proteína es un buen blanco molecular para tratar las infecciones latentes de tuberculosis?

# %% [markdown]
# Sí, consideramos que lo es. Hasta ahora vimos que al atacar el bacilo, este comienza a generar mucha más de esta proteína al estar con falta de oxígeno o al estar bajo estrés. Esto puede indicar que la bacteria requiere de esta proteína para sobrevivir en esas situaciones. Más adelante confirmamos esto, ya que la proteína resulta ser esencial para la bacteria. Es decir, si se pudiera bloquar esta, la bacteria no podría sobrevivir. Y por último observamos que la proteína resulta ser drogable. Es decir, el fármaco que la bloquea tiene un alto porcentaje de acción. Por todo esto es que consideramos que es un buen blanco para tratarlas.

# %% [markdown]
#  # 2. Filtrando proteínas para seleccionar blancos.

# %% [markdown]
# (Se usó prioritize targets - Leishmania major Friedlin)

# %% [markdown]
# ## a. Dentro de la solapa “Filter” seleccione el botón “Metadata” y haga click en “human offtarget” y “hit in deg” (mantenga los valores default). Not que puede cambiar los parámetros “operation” y “value”, pero deje los default. Luego haga click en “Refresh”. ¿Cuántas proteínas componen el subconjunto de las proteínas que quedaron? ¿Qué criterios cumplen dichas proteínas?

# %% [markdown]
# ![image.png](attachment:b2fca049-36ce-4338-a642-51af790448fa.png)

# %% [markdown]
# 2316 proteínas componen el subconjunto.
# Las proteínas cumplen los siguientes criterios:
# Human offtarget; Filtra y se queda con las proteínas que no tienen una alta identidad con las humanas.
# Hit in deg; Tiene un hit en la base de datos de genes esenciales.

# %% [markdown]
# ## b. Ahora seleccione el botón “Structure” y haga click en “druggability”. Cambie el valor de corte (por default 0.5) a 0.7 para seleccionar aquellas proteínas que son altamente drogables. ¿Por qué el valor default será 0.5? Ahora dentro del botón “Pocket” clickee “pocket with csa”. ¿Cuántas proteínas quedaron luego de aplicar los filtros? ¿Qué características tienen? ¿Los considera blancos prometedores?

# %% [markdown]
# Se suele utilizar el valor 0.5 ya que es el punto medio. Es decir, a partir de 0.5 es "más drogable que no drogable". Pero al subirlo a 0.7 se vuelve mucho más exigente la condición de drogable.

# %% [markdown]
# ![image.png](attachment:fa7d23e9-da38-46d1-87a5-2527b0fc56ba.png)

# %% [markdown]
# Quedaron 381 proteínas luego de aplicar los filtros. Estas tienen, además de las características mencionadas en el item a (human offtarget + hit in deg), una alta drogabilidad y la estructura de la proteína tiene al menos un residuo dentro de ese bolsillo reportado en la base de datos del Atlas de Sitios Catalíticos (CSA) (traducción de la definición dada en el programa mismo). Por estas condiciones es que las proteínas que quedaron son consideradas blancos prometedores (siguiendo la misma lógica del objetivo 1 item d).

# %% [markdown]
# ## c. Ahora vuelva a filtrar para quedarse con las proteínas que estén anotadas el término GO “intracellular signal transduction” (dentro del botón “Biological process”). Utilizando una simple serie de filtros usted obtuvo una serie de blancos atractivos para el desarrollo de drogas en L. Major.’ ¿Está de acuerdo con esta afirmación?¿Por qué??vo

# %% [markdown]
# Sí, estamos de acuerdo. Ya con la filtración anterior considerabamos que teníamos preseleccionadas proteínas que podían ser buenos blancos prometedores, y en este último paso filtramos estas con intracellular signal transduction. Con esto nos quedamos solo con las proteínas que, además de cumplir los anteriores requisitos, son las encargadas de las vías de comunicación celular. Al atacar estas proteínas el parásito queda incomunicado de su entorno, por lo que no va a tener una reacción al ser combatido.

# %% [markdown]
# # 3. Utilización de Target-Pathogen para el ranqueo y la priorización de blancos.

# %% [markdown]
# - Entre en Tutorial y realice el tutorial interactivo de “Target prioritization”.
# - Ingrese al genoma de M. tuberculosis y seleccione “Prioritize Targets”
# - Ahora filtre las proteínas que sean drogables (“Structure” → “Druggability”
# Quédese con aquellas cuya drogabilidad sea mayor a 0.5), que no presenten
# similitud con proteínas humanas (“metadata” → “human offtarget”) y que
# sean esenciales (“metadata” →“essentiality”). Observe la distribución de
# esencialidad, drogabilidad y off-target (“Show distribution”).

# %% [markdown]
# ## a. ¿Qué conclusiones puede sacar?

# %% [markdown]
# ![image.png](attachment:4c04c8de-1e8e-4c76-9ac7-805ed25415fe.png)

# %% [markdown]
# Viendo este gráfico podemos afirmar que una gran mayoría de estas proteínas son muy drogables

# %% [markdown]
# ![image.png](attachment:9ad03733-7fd5-4367-9820-a216be0bbe99.png)

# %% [markdown]
# Esto nos muestra que la gran mayoría de las proteínas no son esenciales, por lo que es un filtro de suma importancia al buscar los blancos potenciales.

# %% [markdown]
# ![image.png](attachment:c5706e7a-d7c9-43bb-b370-2c984cd0f888.png)

# %% [markdown]
# Por último, viendo este gráfico podemos afirmar que casi ninguna de estas proteínas se parecen a las humanas

# %% [markdown]
# ## En la solapa “Score” haga click en Metadata y Pathways y seleccione en cada una de las propiedades deseadas (overexpression stress, overexpression starvation, overexpression infection, overexpression hypoxia, chokepoint, centrality). La división por cuatro y por dos respectivamente se realiza para darle el mismo peso al componente de expresión y al componente metabólico de la fórmula. Dado que Target solo permite multiplicar por un coeficiente usted puede asignar un coeficiente de 0.25 y 0.5 (a las variables que desea dividir por cuatro y por dos respectivamente).e). se

# %% [markdown]
# ### a. ¿Cuáles son las cinco proteínas con valores más altos?

# %% [markdown]
# ![Captura de pantalla 2026-06-20 184214.png](attachment:77757dff-0085-412b-95f0-e1e43f73b523.png)

# %% [markdown]
# Y las 5 proteínas con mayor score son:

# %% [markdown]
# ![image.png](attachment:29d78101-9be4-4cbb-a474-420375966731.png)

# %% [markdown]
# ### b. Repasando la expresión de scoring ¿Qué representaría un score cercano a 2??

# %% [markdown]
# Un score cercano a 2 representa que la proteína es un blanco candidato importante, ya que significa que esta tiene una sobreexpresión bajo las 4 condiciones distintas. Como vimos, que la proteína este sobreexpresada significa que resulta indispensable para el parásito cuando es atacado. Al mismo tiempo, la variable chokepoint es 1 si la proteína es un "cuello de botella". En items anteriores vimos que esto contribuye a que sea un potencial blanco. Por último, la variable centrality es muy importante ya que si es alta significa que al atacar la proteína se va a estar atacando un núcleo de conexión.

# %% [markdown]
# ### c. ¿Cuál es el valor de la centralidad de moeB1 (Rv3206c)? Observe la distribución de centralidad de las proteínas y responda: es moeB1 de las proteínas más centrales? ¿Qué podría decir acerca de esta proteína como potencial blanco molecular para el desarrollo de una droga para combatir la tuberculosis?

# %% [markdown]
# ![image.png](attachment:604e831d-cf3d-4e26-b5dc-4a1346a5d7c5.png)

# %% [markdown]
# Tiene una centralidad de 0.02.

# %% [markdown]
# La distribución de centralidad es:

# %% [markdown]
# ![image.png](attachment:ec26787d-13d0-426e-ad3a-09e8a7584db8.png)

# %% [markdown]
# De hecho no lo es. Se encuentra con la mayoria entre 0.0 y 0.1 (con 0.02). Hay solamente cerca de 100 proteínas con una centralidad mayor a 0.1. Pero a pesar de tener una centralidad baja sigue siendo un gran blanco candidato. Esto es porque, al observar las otras variables, vemos que chockepoint = true (por lo que compensa de alguna manera su baja centralidad siendo un cuello de botella) y que tiene una sobreexpresión en 3 de 4 condiciones. además, teniendo en cuenta los filtros previos ya sabemos que es una proteína esencial para la bacteria, segura para el paciente y altamente drogable.

# %% [markdown]
# # 4. Cómo elegir vías metabólicas adecuadas para el desarrollo de drogas

# %% [markdown]
# ## a. ¿Por qué uno elegiría priorizar vías metabólicas completas?

# %% [markdown]
# Una ventaja fundamental de este enfoque es la posibilidad de
# diseñar terapias combinadas que ataquen sinérgicamente más de una proteína
# dentro de la misma v. De esta manera se busca lograr un ataque más efectivo.a.

# %% [markdown]
# ## b. Diseñe una función de scoring para encontrar vías metabólicas adecuadas en el diseño de fármacos frente a K. pneumoniae. ¿Qué características tendría en cuenta?a?

# %% [markdown]
# Basandonme en lo visto en los items anteriores, considero que es fundamental tener en cuenta la condición de human off target, para no correr el riesgo de dañar al paciente. Además, tener en cuenta si la vía está sobreexpresada bajo ciertas condiciones. A esto le sumaría que tenga una alta drogabilidad y que sea un chokepoint.

# %% [markdown]
# Así, la función nos quedaría de la forma:

# %% [markdown]
# ### S = 0.4 x human off target + 0.25 x sobreexpresión + 0.25 x drogabilidad + 0.1 x chokepoint

# %% [markdown]
# ![image.png](attachment:ee31b08a-0675-4ee7-8f6e-eb1a620d4b60.png)

# %% [markdown]
# ## c. Cuál es la diferencia entre “conserved pathogen bbh norm” y “conserved pathogen bbh”? ¿Cuál utilizaría usted?

# %% [markdown]
# Nosotros consideramos mejor utilizar "conserved pathogen bbh norm" ya que el resultado está normalizado. Así, se vuelve más fácil de comparar con las otras variables de la función.

# %% [markdown]
# Por el momento, la función de scoring luce así:

# %% [markdown]
# ![image.png](attachment:616fe5a4-bc19-4a53-8a99-c648891dd0b4.png)

# %% [markdown]
# ## d. Usted podría agregar un término P (“Metadata”→ “overexpressed in polymyxin”). ¿Cómo haría para darle tanto peso a este parámetro como a la suma de todos los demás?ás?

# %% [markdown]
# Le dimos un peso de 0.5 a este nuevo término mientras que los otros 5 términos poseen un mismo peso de 0.10.

# %% [markdown]
# Así queda la función:

# %% [markdown]
# ![image.png](attachment:ed5154cd-c05e-49b2-aafa-52a03f71387c.png)

# %% [markdown]
# ## e. ¿Qué conclusiones podría sacar acerca de las vías con mayor valor de score??

# %% [markdown]
# ![image.png](attachment:5bfb8da9-3608-4d70-b498-a495039b702f.png)

# %% [markdown]
# Estas resultaron ser las vías con mayor score. Son los blancos candidatos (siguiendo con las decisiones tomadas para armar la función de score)  ya que son las que más cumplen con los términos puestos. Al tener tanto peso, nos aseguramos de que estas vías están sobreexpresadas en poliximina, por lo que en este escenario son vitales para la bacteria. Sin embargo, no se le dio mucho peso ni a la drogabilidad ni al human off target. Esto puede resultar peligroso ya que las vías estas pueden no actuar de manera esperada al ingerir la droga, o incluso pueden afectar al paciente ya que no nos estamos asegurando realmente de que no lo afecten. Por esto último es que en la función de scoring propuesta le dimos tanto peso a este parámetro.
